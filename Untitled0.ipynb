# %% [markdown]
# <a href="https://colab.research.google.com/github/Santiagx2001/Backend_Turnos/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Resumen de Video en clase:

# %%
El video "Gerencia de Software y Entrega de Valor Estratégico" explica cómo la gestión moderna de proyectos de software trasciende la excelencia técnica para enfocarse en la creación de valor comercial medible

A continuación se presentan los puntos clave desglosados en el explicador:
Evolución del PMBOK (8.ª Edición): La metodología abandona las estructuras rígidas y burocráticas del pasado, reestructurando los antiguos grupos de procesos en cinco áreas de enfoque prácticas que facilitan la entrega de valor en el mundo real y en cualquier industria

Alineación de Portafolios y Operaciones: Ningún proyecto debe operar como un elemento aislado. La estrategia funciona en cascada desde la visión organizacional hasta la gestión de portafolios, conectando la estrategia ejecutiva con la ejecución técnica para asegurar que no se escriba código sin un propósito predefinido

El Sistema de Entrega de Valor: Se promueve la transición desde la simple entrega de resultados técnicos (como un paquete de código a tiempo) hacia un enfoque sistémico centrado en la adopción efectiva del software. El valor por unidad de inversión se establece como la métrica suprema del éxito.
Tutorial de Viabilidad en 3 Pasos: Para justificar estratégicamente un proyecto y prevenir el desperdicio de capital, se deben seguir tres pasos secuenciales: auditar la necesidad comercial real, definir objetivos medibles y establecer criterios de éxito con métricas financieras concretas.
Caso de Negocio vs. Acta Constitutiva:
 - Caso de Negocio (Business Case): Es el estudio de viabilidad económica y ancla financiera que demuestra los beneficios del proyecto mediante métricas como el Retorno de Inversión (ROI) y el Valor Actual Neto (VAN).
 - Acta Constitutiva (Project Charter): Es el documento de mandato legal que autoriza formalmente la existencia del proyecto y otorga al director la autoridad institucional para asignar recursos.
Herramientas de Gobierno y Liderazgo: El arsenal para un control integral requiere dominar herramientas como la matriz RACI, la Estructura de Desglose del Trabajo (EDT), diagramas de Gantt, tableros de valor ganado y registros de riesgos. El liderazgo técnico reside en integrar la disciplina metodológica con la alineación estratégica y la creación sistemática de valor.
